# %%
import pickle
import os
import traceback
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from collections import defaultdict
import pandas as pd

# %%
path = './temp_more_algo'
pathList = os.listdir(path)

all_results = []
# 遍历列表中的文件名
for file in pathList:
    # 使用join函数对路径进行拼接，然后构成绝对路径
    if 'pkl' not in file:
        continue
    abs_path = os.path.join(path,file)
    print(abs_path)
    try:
        with open(abs_path, 'rb') as file:
            result = pickle.load(file)
        all_results.append(result)
    except Exception as e:
        traceback.print_exc()
    
    # print(result)
# Out:
# ./temp_more_algo/debug_result_(28, 31, 1, 4).pkl
# ./temp_more_algo/debug_result_(19, 22, 1, 3).pkl
# ./temp_more_algo/debug_result_(49, 52, 3, 2).pkl
# ./temp_more_algo/debug_result_(6, 9, 3, 4).pkl
# ./temp_more_algo/debug_result_(49, 52, 4, 4).pkl
# ./temp_more_algo/debug_result_(40, 43, 4, 3).pkl
# ./temp_more_algo/debug_result_(10, 13, 4, 6).pkl
# ./temp_more_algo/debug_result_(10, 13, 4, 2).pkl
# ./temp_more_algo/debug_result_(49, 52, 3, 3).pkl
# ./temp_more_algo/debug_result_(46, 49, 1, 2).pkl
# ./temp_more_algo/debug_result_(28, 31, 2, 2).pkl
# ./temp_more_algo/debug_result_(34, 37, 4, 3).pkl
# ./temp_more_algo/debug_result_(13, 16, 1, 5).pkl
# ./temp_more_algo/debug_result_(6, 9, 1, 4).pkl
# ./temp_more_algo/debug_result_(22, 25, 2, 3).pkl
# ./temp_more_algo/debug_result_(31, 34, 1, 3).pkl
# ./temp_more_algo/debug_result_(13, 16, 3, 2).pkl
# ./temp_more_algo/debug_result_(31, 34, 3, 3).pkl
# ./temp_more_algo/debug_result_(9, 12, 4, 4).pkl
# ./temp_more_algo/debug_result_(43, 46, 3, 2).pkl
# ./temp_more_algo/debug_result_(31, 34, 4, 3).pkl
# ./temp_more_algo/debug_result_(25, 28, 1, 2).pkl
# ./temp_more_algo/debug_result_(13, 16, 3, 3).pkl
# ./temp_more_algo/debug_result_(19, 22, 4, 3).pkl
# ./temp_more_algo/debug_result_(37, 40, 2, 2).pkl
# ./temp_more_algo/debug_result_(31, 34, 3, 2).pkl
# ./temp_more_algo/debug_result_(16, 19, 3, 6).pkl
# ./temp_more_algo/debug_result_(43, 46, 3, 4).pkl
# ./temp_more_algo/debug_result_(19, 22, 2, 2).pkl
# ./temp_more_algo/debug_result_(16, 19, 2, 5).pkl
# ./temp_more_algo/debug_result_(31, 34, 2, 2).pkl
# ./temp_more_algo/debug_result_(19, 22, 3, 6).pkl
# ./temp_more_algo/debug_result_(31, 34, 4, 2).pkl
# ./temp_more_algo/debug_result_(31, 34, 1, 2).pkl
# ./temp_more_algo/debug_result_(40, 43, 2, 2).pkl
# ./temp_more_algo/debug_result_(22, 25, 3, 4).pkl
# ./temp_more_algo/debug_result_(43, 46, 2, 2).pkl
# ./temp_more_algo/debug_result_(10, 13, 4, 4).pkl
# ./temp_more_algo/debug_result_(25, 28, 4, 2).pkl
# ./temp_more_algo/debug_result_(46, 49, 3, 2).pkl
# ./temp_more_algo/debug_result_(6, 9, 2, 4).pkl
# ./temp_more_algo/debug_result_(22, 25, 4, 5).pkl
# ./temp_more_algo/debug_result_(37, 40, 3, 3).pkl
# ./temp_more_algo/debug_result_(13, 16, 1, 3).pkl
# ./temp_more_algo/debug_result_(40, 43, 2, 4).pkl
# ./temp_more_algo/debug_result_(9, 12, 3, 3).pkl
# ./temp_more_algo/debug_result_(9, 12, 2, 4).pkl
# ./temp_more_algo/debug_result_(16, 19, 4, 5).pkl
# ./temp_more_algo/debug_result_(16, 19, 1, 4).pkl
# ./temp_more_algo/debug_result_(28, 31, 4, 4).pkl
# ./temp_more_algo/debug_result_(16, 19, 2, 3).pkl
# ./temp_more_algo/debug_result_(49, 52, 1, 4).pkl
# ./temp_more_algo/debug_result_(19, 22, 2, 4).pkl
# ./temp_more_algo/debug_result_(37, 40, 1, 3).pkl
# ./temp_more_algo/debug_result_(13, 16, 1, 6).pkl
# ./temp_more_algo/debug_result_(22, 25, 4, 3).pkl
# ./temp_more_algo/debug_result_(46, 49, 4, 2).pkl
# ./temp_more_algo/debug_result_(43, 46, 2, 4).pkl
# ./temp_more_algo/debug_result_(13, 16, 4, 2).pkl
# ./temp_more_algo/debug_result_(16, 19, 4, 3).pkl
# ./temp_more_algo/debug_result_(49, 52, 2, 2).pkl
# ./temp_more_algo/debug_result_(34, 37, 3, 3).pkl
# ./temp_more_algo/debug_result_(6, 9, 1, 3).pkl
# ./temp_more_algo/debug_result_(49, 52, 2, 4).pkl
# ./temp_more_algo/debug_result_(25, 28, 3, 2).pkl
# ./temp_more_algo/debug_result_(19, 22, 1, 5).pkl
# ./temp_more_algo/debug_result_(16, 19, 1, 6).pkl
# ./temp_more_algo/debug_result_(40, 43, 1, 3).pkl
# ./temp_more_algo/debug_result_(49, 52, 4, 2).pkl
# ./temp_more_algo/debug_result_(22, 25, 1, 4).pkl
# ./temp_more_algo/debug_result_(6, 9, 4, 3).pkl
# ./temp_more_algo/debug_result_(37, 40, 4, 3).pkl
# ./temp_more_algo/debug_result_(13, 16, 2, 4).pkl
# ./temp_more_algo/debug_result_(37, 40, 2, 4).pkl
# ./temp_more_algo/debug_result_(34, 37, 1, 3).pkl
# ./temp_more_algo/debug_result_(16, 19, 2, 4).pkl
# ./temp_more_algo/debug_result_(34, 37, 3, 4).pkl
# ./temp_more_algo/debug_result_(49, 52, 4, 3).pkl
# ./temp_more_algo/debug_result_(34, 37, 2, 3).pkl
# ./temp_more_algo/debug_result_(40, 43, 1, 4).pkl
# ./temp_more_algo/debug_result_(19, 22, 4, 4).pkl
# ./temp_more_algo/debug_result_(13, 16, 3, 6).pkl
# ./temp_more_algo/debug_result_(13, 16, 2, 6).pkl
# ./temp_more_algo/debug_result_(16, 19, 3, 5).pkl
# ./temp_more_algo/debug_result_(9, 12, 3, 4).pkl
# ./temp_more_algo/debug_result_(10, 13, 2, 5).pkl
# ./temp_more_algo/debug_result_(10, 13, 3, 2).pkl
# ./temp_more_algo/debug_result_(28, 31, 3, 2).pkl
# ./temp_more_algo/debug_result_(16, 19, 3, 2).pkl
# ./temp_more_algo/debug_result_(10, 13, 1, 2).pkl
# ./temp_more_algo/debug_result_(31, 34, 2, 4).pkl
# ./temp_more_algo/debug_result_(43, 46, 1, 4).pkl
# ./temp_more_algo/debug_result_(46, 49, 3, 3).pkl
# ./temp_more_algo/debug_result_(16, 19, 1, 2).pkl
# ./temp_more_algo/debug_result_(13, 16, 4, 4).pkl
# ./temp_more_algo/debug_result_(16, 19, 4, 4).pkl
# ./temp_more_algo/debug_result_(10, 13, 2, 4).pkl
# ./temp_more_algo/debug_result_(10, 13, 1, 3).pkl
# ./temp_more_algo/debug_result_(34, 37, 2, 4).pkl
# ./temp_more_algo/debug_result_(25, 28, 3, 4).pkl
# ./temp_more_algo/debug_result_(19, 22, 1, 6).pkl
# ./temp_more_algo/debug_result_(46, 49, 2, 2).pkl
# ./temp_more_algo/debug_result_(28, 31, 3, 4).pkl
# ./temp_more_algo/debug_result_(16, 19, 4, 6).pkl
# ./temp_more_algo/debug_result_(10, 13, 1, 4).pkl
# ./temp_more_algo/debug_result_(10, 13, 2, 6).pkl
# ./temp_more_algo/debug_result_(16, 19, 1, 3).pkl
# ./temp_more_algo/debug_result_(25, 28, 2, 4).pkl
# ./temp_more_algo/debug_result_(25, 28, 3, 3).pkl
# ./temp_more_algo/debug_result_(13, 16, 1, 2).pkl
# ./temp_more_algo/debug_result_(13, 16, 3, 4).pkl
# ./temp_more_algo/debug_result_(34, 37, 1, 4).pkl
# ./temp_more_algo/debug_result_(10, 13, 1, 5).pkl
# ./temp_more_algo/debug_result_(25, 28, 4, 3).pkl
# ./temp_more_algo/debug_result_(19, 22, 4, 6).pkl
# ./temp_more_algo/debug_result_(22, 25, 3, 5).pkl
# ./temp_more_algo/debug_result_(6, 9, 3, 3).pkl
# ./temp_more_algo/debug_result_(22, 25, 1, 3).pkl
# ./temp_more_algo/debug_result_(25, 28, 2, 2).pkl
# ./temp_more_algo/debug_result_(22, 25, 4, 4).pkl
# ./temp_more_algo/debug_result_(9, 12, 1, 3).pkl
# ./temp_more_algo/debug_result_(19, 22, 2, 5).pkl
# ./temp_more_algo/debug_result_(9, 12, 4, 3).pkl
# ./temp_more_algo/debug_result_(10, 13, 3, 6).pkl
# ./temp_more_algo/debug_result_(40, 43, 3, 2).pkl
# ./temp_more_algo/debug_result_(40, 43, 3, 3).pkl
# ./temp_more_algo/debug_result_(34, 37, 4, 4).pkl
# ./temp_more_algo/debug_result_(19, 22, 4, 5).pkl
# ./temp_more_algo/debug_result_(28, 31, 1, 2).pkl
# ./temp_more_algo/debug_result_(9, 12, 1, 4).pkl
# ./temp_more_algo/debug_result_(13, 16, 2, 3).pkl
# ./temp_more_algo/debug_result_(34, 37, 1, 2).pkl
# ./temp_more_algo/debug_result_(10, 13, 3, 3).pkl
# ./temp_more_algo/debug_result_(49, 52, 3, 4).pkl
# ./temp_more_algo/debug_result_(22, 25, 4, 2).pkl
# ./temp_more_algo/debug_result_(10, 13, 3, 5).pkl
# ./temp_more_algo/debug_result_(37, 40, 1, 2).pkl
# ./temp_more_algo/debug_result_(19, 22, 1, 2).pkl
# ./temp_more_algo/debug_result_(37, 40, 1, 4).pkl
# ./temp_more_algo/debug_result_(19, 22, 3, 3).pkl
# ./temp_more_algo/debug_result_(13, 16, 3, 5).pkl
# ./temp_more_algo/debug_result_(46, 49, 3, 4).pkl
# ./temp_more_algo/debug_result_(37, 40, 4, 2).pkl
# ./temp_more_algo/debug_result_(46, 49, 2, 4).pkl
# ./temp_more_algo/debug_result_(22, 25, 2, 5).pkl
# ./temp_more_algo/debug_result_(19, 22, 4, 2).pkl
# ./temp_more_algo/debug_result_(28, 31, 4, 3).pkl
# ./temp_more_algo/debug_result_(28, 31, 2, 3).pkl
# ./temp_more_algo/debug_result_(43, 46, 4, 3).pkl
# ./temp_more_algo/debug_result_(43, 46, 1, 2).pkl
# ./temp_more_algo/debug_result_(34, 37, 4, 2).pkl
# ./temp_more_algo/debug_result_(19, 22, 3, 2).pkl
# ./temp_more_algo/debug_result_(22, 25, 3, 2).pkl
# ./temp_more_algo/debug_result_(43, 46, 4, 2).pkl
# ./temp_more_algo/debug_result_(40, 43, 2, 3).pkl
# ./temp_more_algo/debug_result_(16, 19, 2, 6).pkl
# ./temp_more_algo/debug_result_(10, 13, 3, 4).pkl
# ./temp_more_algo/debug_result_(43, 46, 1, 3).pkl
# ./temp_more_algo/debug_result_(46, 49, 1, 3).pkl
# ./temp_more_algo/debug_result_(19, 22, 1, 4).pkl
# ./temp_more_algo/debug_result_(46, 49, 1, 4).pkl
# ./temp_more_algo/debug_result_(19, 22, 3, 5).pkl
# ./temp_more_algo/debug_result_(13, 16, 1, 4).pkl
# ./temp_more_algo/debug_result_(6, 9, 4, 4).pkl
# ./temp_more_algo/debug_result_(25, 28, 4, 4).pkl
# ./temp_more_algo/debug_result_(10, 13, 1, 6).pkl
# ./temp_more_algo/debug_result_(49, 52, 2, 3).pkl
# ./temp_more_algo/debug_result_(13, 16, 2, 5).pkl
# ./temp_more_algo/debug_result_(37, 40, 2, 3).pkl
# ./temp_more_algo/debug_result_(40, 43, 3, 4).pkl
# ./temp_more_algo/debug_result_(34, 37, 2, 2).pkl
# ./temp_more_algo/debug_result_(46, 49, 4, 4).pkl
# ./temp_more_algo/debug_result_(19, 22, 2, 3).pkl
# ./temp_more_algo/debug_result_(13, 16, 4, 5).pkl
# ./temp_more_algo/debug_result_(6, 9, 2, 3).pkl
# ./temp_more_algo/debug_result_(31, 34, 2, 3).pkl
# ./temp_more_algo/debug_result_(13, 16, 4, 6).pkl
# ./temp_more_algo/debug_result_(37, 40, 3, 2).pkl
# ./temp_more_algo/debug_result_(13, 16, 2, 2).pkl
# ./temp_more_algo/debug_result_(13, 16, 4, 3).pkl
# ./temp_more_algo/debug_result_(22, 25, 2, 4).pkl
# ./temp_more_algo/debug_result_(28, 31, 3, 3).pkl
# ./temp_more_algo/debug_result_(49, 52, 1, 2).pkl
# ./temp_more_algo/debug_result_(31, 34, 3, 4).pkl
# ./temp_more_algo/debug_result_(46, 49, 4, 3).pkl
# ./temp_more_algo/debug_result_(31, 34, 1, 4).pkl
# ./temp_more_algo/debug_result_(28, 31, 1, 3).pkl
# ./temp_more_algo/debug_result_(40, 43, 4, 2).pkl
# ./temp_more_algo/debug_result_(19, 22, 2, 6).pkl
# ./temp_more_algo/debug_result_(40, 43, 4, 4).pkl
# ./temp_more_algo/debug_result_(31, 34, 4, 4).pkl
# ./temp_more_algo/debug_result_(16, 19, 1, 5).pkl
# ./temp_more_algo/debug_result_(40, 43, 1, 2).pkl
# ./temp_more_algo/debug_result_(19, 22, 3, 4).pkl
# ./temp_more_algo/debug_result_(49, 52, 1, 3).pkl
# ./temp_more_algo/debug_result_(16, 19, 3, 3).pkl
# ./temp_more_algo/debug_result_(22, 25, 1, 2).pkl
# ./temp_more_algo/debug_result_(16, 19, 4, 2).pkl
# ./temp_more_algo/debug_result_(16, 19, 3, 4).pkl
# ./temp_more_algo/debug_result_(22, 25, 3, 3).pkl
# ./temp_more_algo/debug_result_(10, 13, 4, 5).pkl
# ./temp_more_algo/debug_result_(43, 46, 2, 3).pkl
# ./temp_more_algo/debug_result_(10, 13, 2, 3).pkl
# ./temp_more_algo/debug_result_(9, 12, 2, 3).pkl
# ./temp_more_algo/debug_result_(46, 49, 2, 3).pkl
# ./temp_more_algo/debug_result_(34, 37, 3, 2).pkl
# ./temp_more_algo/debug_result_(16, 19, 2, 2).pkl
# ./temp_more_algo/debug_result_(10, 13, 2, 2).pkl
# ./temp_more_algo/debug_result_(37, 40, 4, 4).pkl
# ./temp_more_algo/debug_result_(28, 31, 2, 4).pkl
# ./temp_more_algo/debug_result_(22, 25, 1, 5).pkl
# ./temp_more_algo/debug_result_(25, 28, 2, 3).pkl
# ./temp_more_algo/debug_result_(37, 40, 3, 4).pkl
# ./temp_more_algo/debug_result_(43, 46, 3, 3).pkl
# ./temp_more_algo/debug_result_(25, 28, 1, 3).pkl
# ./temp_more_algo/debug_result_(28, 31, 4, 2).pkl
# ./temp_more_algo/debug_result_(22, 25, 2, 2).pkl
# ./temp_more_algo/debug_result_(43, 46, 4, 4).pkl
# ./temp_more_algo/debug_result_(10, 13, 4, 3).pkl
# ./temp_more_algo/debug_result_(25, 28, 1, 4).pkl

# %%
len(pathList), len(all_results)
# Out:
# (220, 220)

# %%
# result  = {
#     'key': key,
#     'alg2n_qubit2success_num': to_dict(alg2n_qubit2success_num),
#     'alg2n_qubit2bug_num': to_dict(alg2n_qubit2bug_num), 
#     'alg2n_qubit2error_num': to_dict(alg2n_qubit2error_num), 
#     'alg2n_qubit2identify_num': to_dict(alg2n_qubit2identify_num) 
# }

# %%
all_results[0]
# Out:
# {'key': (28, 31, 1, 4),
#  'alg2n_qubit2success_num': {'hamiltonian_simulation': {28: 1, 30: 1},
#   'qknn': {29: 1},
#   'qsvm': {30: 1},
#   'ising': {29: 1, 30: 1},
#   'qft': {30: 1},
#   'ghz': {28: 1, 29: 1, 30: 1},
#   'qft_inverse': {29: 1},
#   'qnn': {29: 1},
#   'qugan': {29: 1},
#   'deutsch_jozsa': {28: 1, 29: 1},
#   'bernstein_vazirani': {29: 1},
#   'multiplier': {30: 1},
#   'qec_5_x': {30: 1}},
#  'alg2n_qubit2bug_num': {'hamiltonian_simulation': {28: 1, 29: 1, 30: 1},
#   'qknn': {28: 1, 29: 1, 30: 1},
#   'qsvm': {28: 1, 29: 1, 30: 1},
#   'vqc': {28: 1, 29: 1, 30: 1},
#   'ising': {28: 1, 29: 1, 30: 1},
#   'qft': {28: 1, 29: 1, 30: 1},
#   'ghz': {28: 1, 29: 1, 30: 1},
#   'qft_inverse': {28: 1, 29: 1, 30: 1},
#   'swap': {29: 1},
#   'qnn': {29: 1},
#   'qugan': {29: 1},
#   'simon': {28: 1, 30: 1},
#   'deutsch_jozsa': {28: 1, 29: 1, 30: 1},
#   'bernstein_vazirani': {28: 1, 29: 1, 30: 1},
#   'multiplier': {30: 1},
#   'qec_5_x': {30: 1}},
#  'alg2n_qubit2error_num': {'hamiltonian_simulation': {29: 1, 30: 3},
#   'qknn': {28: 1},
#   'qsvm': {28: 1, 29: 1},
#   'vqc': {28: 9, 29: 9, 30: 5},
#   'ising': {28: 7, 29: 4, 30: 4},
#   'ghz': {28: 1, 29: 1},
#   'qft_inverse': {28: 1, 29: 1},
#   'qnn': {29: 1},
#   'deutsch_jozsa': {29: 2, 30: 1},
#   'bernstein_vazirani': {29: 1},
#   'qec_5_x': {30: 1}},
#  'alg2n_qubit2identify_num': {'hamiltonian_simulation': {28: 165,
#    29: 171,
#    30: 177},
#   'qknn': {28: 42, 29: 44, 30: 45},
#   'qsvm': {28: 274, 29: 284, 30: 294},
#   'vqc': {28: 1873, 29: 1998, 30: 2127},
#   'ising': {28: 302, 29: 313, 30: 324},
#   'qft': {28: 420, 29: 449, 30: 480},
#   'ghz': {28: 28, 29: 29, 30: 30},
#   'qft_inverse': {28: 435, 29: 462, 30: 495},
#   'swap': {29: 44},
#   'qnn': {29: 124},
#   'qugan': {29: 96},
#   'simon': {28: 48, 30: 54},
#   'deutsch_jozsa': {28: 107, 29: 110, 30: 113},
#   'bernstein_vazirani': {28: 68, 29: 75, 30: 72},
#   'multiplier': {30: 297},
#   'qec_5_x': {30: 42}}}

# %%
qubit_step = 5
min_qubit, max_qubit  = 10, 49
bug_num_ranges = [
    (start, start + qubit_step)
    for start in range(min_qubit, max_qubit, qubit_step)
]

# %%
def findRange(value, qubit_ranges):
    for start, end in qubit_ranges:
        if value >= start and value < end:
            return (start, end)
    return None

# %%
alg2n_qubit2success_num = defaultdict(lambda: defaultdict(int))
alg2n_qubit2bug_num = defaultdict(lambda: defaultdict(int))

# alg_names = set()
# qubit_nums = set()
for result in all_results:
    min_qubit_num, max_qubit_num, bug_num, max_step = result['key']
    if max_step == 4:
        
        for alg_name, n_qubit2success_num in result['alg2n_qubit2success_num'].items():
            for n_qubit, success_num in n_qubit2success_num.items():
                # alg2n_qubit2success_num[alg_name][n_qubit] += success_num 
                alg2n_qubit2success_num[alg_name][findRange(n_qubit,bug_num_ranges)] += success_num 
                
            # alg_names.add(alg_name)
            # qubit_nums.add((min_qubit_num,max_qubit_num))

        for alg_name, n_qubit2bug_num in result['alg2n_qubit2bug_num'].items():
            for n_qubit, bug_num in n_qubit2bug_num.items():
                # alg2n_qubit2bug_num[alg_name][n_qubit] += bug_num
                alg2n_qubit2bug_num[alg_name][findRange(n_qubit,bug_num_ranges)] += bug_num  
                
# alg_names = list(alg_names)
# qubit_nums = list(qubit_nums)
# alg_names.sort()
# qubit_nums.sort()
# alg_names, qubit_nums

# %%
def combine(dict1, dict2, default_value = 1):
    all_values = []
    new_dict = defaultdict(lambda: defaultdict(lambda: default_value))
    for k1, v1 in dict1.items():
        for k2, v2 in v1.items():
            new_dict[k1][k2] = v2 / dict2[k1][k2]
            all_values.append(v2 / dict2[k1][k2])
    
    return new_dict, np.array(all_values)

# %%
alg2n_qubit2success_rate, all_values = combine(alg2n_qubit2success_num, alg2n_qubit2bug_num)
alg2n_qubit2success_rate, np.mean(all_values)
# Out:
# (defaultdict(<function __main__.combine.<locals>.<lambda>()>,
#              {'hamiltonian_simulation': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.45,
#                            (30, 35): 0.55,
#                            None: 0.5,
#                            (45, 50): 0.5,
#                            (10, 15): 0.6785714285714286,
#                            (20, 25): 0.55,
#                            (40, 45): 0.25,
#                            (15, 20): 0.6,
#                            (35, 40): 0.45}),
#               'qknn': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.8,
#                            None: 0.7916666666666666,
#                            (45, 50): 0.7,
#                            (10, 15): 0.8214285714285714,
#                            (40, 45): 0.5,
#                            (20, 25): 0.7,
#                            (15, 20): 0.8,
#                            (30, 35): 0.7,
#                            (35, 40): 0.55}),
#               'qsvm': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(30, 35): 0.6,
#                            None: 0.5833333333333334,
#                            (10, 15): 0.7142857142857143,
#                            (40, 45): 0.45,
#                            (20, 25): 0.45,
#                            (25, 30): 0.55,
#                            (45, 50): 0.5,
#                            (15, 20): 0.4,
#                            (35, 40): 0.35}),
#               'ising': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.95,
#                            (30, 35): 0.95,
#                            None: 0.9166666666666666,
#                            (45, 50): 1.0,
#                            (10, 15): 0.8928571428571429,
#                            (40, 45): 1.0,
#                            (20, 25): 0.85,
#                            (15, 20): 0.9,
#                            (35, 40): 1.0}),
#               'qft': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(30, 35): 0.85,
#                            None: 0.4583333333333333,
#                            (45, 50): 0.6,
#                            (10, 15): 0.5714285714285714,
#                            (20, 25): 0.55,
#                            (40, 45): 0.6,
#                            (15, 20): 0.6,
#                            (25, 30): 0.3,
#                            (35, 40): 0.65}),
#               'ghz': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 1.0,
#                            (30, 35): 0.95,
#                            None: 0.9166666666666666,
#                            (45, 50): 0.9,
#                            (10, 15): 0.9285714285714286,
#                            (40, 45): 1.0,
#                            (20, 25): 0.9,
#                            (15, 20): 0.95,
#                            (35, 40): 1.0}),
#               'qft_inverse': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.75,
#                            None: 0.7916666666666666,
#                            (45, 50): 0.7,
#                            (10, 15): 0.8928571428571429,
#                            (40, 45): 0.65,
#                            (20, 25): 0.65,
#                            (30, 35): 0.8,
#                            (15, 20): 0.7,
#                            (35, 40): 0.6}),
#               'qnn': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.875,
#                            None: 0.875,
#                            (10, 15): 1.0,
#                            (45, 50): 0.75,
#                            (20, 25): 0.875,
#                            (40, 45): 1.0,
#                            (15, 20): 0.75,
#                            (35, 40): 0.625,
#                            (30, 35): 1.0}),
#               'qugan': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.75,
#                            None: 0.875,
#                            (10, 15): 0.875,
#                            (45, 50): 0.75,
#                            (20, 25): 0.625,
#                            (15, 20): 0.75,
#                            (35, 40): 0.625,
#                            (30, 35): 0.5,
#                            (40, 45): 0.5}),
#               'deutsch_jozsa': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.75,
#                            None: 0.9583333333333334,
#                            (45, 50): 0.95,
#                            (10, 15): 0.8571428571428571,
#                            (40, 45): 0.95,
#                            (20, 25): 0.9,
#                            (15, 20): 0.9,
#                            (35, 40): 0.85,
#                            (30, 35): 0.75}),
#               'bernstein_vazirani': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.4,
#                            None: 0.875,
#                            (45, 50): 0.5,
#                            (10, 15): 0.6785714285714286,
#                            (40, 45): 0.45,
#                            (20, 25): 0.45,
#                            (30, 35): 0.4,
#                            (35, 40): 0.4,
#                            (15, 20): 0.55}),
#               'multiplier': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(30, 35): 1.0,
#                            None: 1.0,
#                            (10, 15): 1.0,
#                            (45, 50): 0.5,
#                            (40, 45): 0.5,
#                            (20, 25): 1.0,
#                            (15, 20): 1.0,
#                            (35, 40): 1.0,
#                            (25, 30): 1.0}),
#               'qec_5_x': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(30, 35): 1.0,
#                            None: 0.5,
#                            (10, 15): 0.75,
#                            (45, 50): 1.0,
#                            (40, 45): 0.75,
#                            (20, 25): 0.75,
#                            (15, 20): 1.0,
#                            (35, 40): 0.25,
#                            (25, 30): 0.5}),
#               'vqc': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {None: 0.7916666666666666,
#                            (45, 50): 0.8,
#                            (10, 15): 0.75,
#                            (40, 45): 0.8,
#                            (20, 25): 0.7,
#                            (15, 20): 0.75,
#                            (25, 30): 0.9,
#                            (30, 35): 0.8,
#                            (35, 40): 0.9}),
#               'swap': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {None: 0.875,
#                            (10, 15): 1.0,
#                            (45, 50): 0.625,
#                            (20, 25): 0.75,
#                            (40, 45): 1.0,
#                            (15, 20): 1.0,
#                            (25, 30): 0.625,
#                            (30, 35): 0.75,
#                            (35, 40): 0.5}),
#               'simon': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {None: 0.6666666666666666,
#                            (10, 15): 0.625,
#                            (40, 45): 0.5,
#                            (20, 25): 0.6666666666666666,
#                            (25, 30): 0.5,
#                            (15, 20): 0.75,
#                            (30, 35): 0.4166666666666667,
#                            (35, 40): 0.5,
#                            (45, 50): 0.375}),
#               'grover': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {None: 1.0,
#                            (10, 15): 0.8928571428571429,
#                            (15, 20): 0.95,
#                            (20, 25): 0.5})}),
#  0.7293034105534106)

# %% [markdown]
# TODO: 找到最大的step

# %%
# # 重新按照qubit的range进行排序
# for

# %%
# index: qubit_nums:
# cols: alg_names

alg_names = list(alg2n_qubit2success_rate.keys())
# qubit_nums = list(range(10, 30))
# qubit_nums.sort()
alg_names.sort()

# alg_names, qubit_nums

data = np.zeros((len(bug_num_ranges) , len(alg_names))) # 先index, 后column

for r_i, qubit_num in enumerate(bug_num_ranges):
    for c_i, alg_name in enumerate(alg_names):
        data[r_i][c_i] = alg2n_qubit2success_rate[alg_name][qubit_num]

df = pd.DataFrame(data, index=bug_num_ranges, columns=alg_names)
fig = sns.heatmap(data=df,cmap='OrRd')
fig.get_figure().savefig('success_rate.svg')
print(data)
# Out:
# [[0.67857143 0.85714286 0.92857143 0.89285714 0.67857143 0.89285714
#   1.         0.75       0.57142857 0.89285714 0.82142857 1.
#   0.71428571 0.875      0.625      1.         0.75      ]
#  [0.55       0.9        0.95       0.95       0.6        0.9
#   1.         1.         0.6        0.7        0.8        0.75
#   0.4        0.75       0.75       1.         0.75      ]
#  [0.45       0.9        0.9        0.5        0.55       0.85
#   1.         0.75       0.55       0.65       0.7        0.875
#   0.45       0.625      0.66666667 0.75       0.7       ]
#  [0.4        0.75       1.         1.         0.45       0.95
#   1.         0.5        0.3        0.75       0.8        0.875
#   0.55       0.75       0.5        0.625      0.9       ]
#  [0.4        0.75       0.95       1.         0.55       0.95
#   1.         1.         0.85       0.8        0.7        1.
#   0.6        0.5        0.41666667 0.75       0.8       ]
#  [0.4        0.85       1.         1.         0.45       1.
#   1.         0.25       0.65       0.6        0.55       0.625
#   0.35       0.625      0.5        0.5        0.9       ]
#  [0.45       0.95       1.         1.         0.25       1.
#   0.5        0.75       0.6        0.65       0.5        1.
#   0.45       0.5        0.5        1.         0.8       ]
#  [0.5        0.95       0.9        1.         0.5        1.
#   0.5        1.         0.6        0.7        0.7        0.75
#   0.5        0.75       0.375      0.625      0.8       ]]

# %%
alg2n_qubit2error_num = defaultdict(lambda: defaultdict(int))
alg2n_qubit2identify_num = defaultdict(lambda: defaultdict(int))

alg_names = set()
qubit_nums = set()
for result in all_results:
    min_qubit_num, max_qubit_num, identify_num, max_step = result['key']
    if max_step == 4:
      
        for alg_name, n_qubit2error_num in result['alg2n_qubit2error_num'].items():
            for n_qubit, error_num in n_qubit2error_num.items():
                # alg2n_qubit2success_num[alg_name][n_qubit] += success_num 
                alg2n_qubit2error_num[alg_name][findRange(n_qubit,bug_num_ranges)] += error_num 
                
            # alg_names.add(alg_name)
            # qubit_nums.add((min_qubit_num,max_qubit_num))

        for alg_name, n_qubit2identify_num in result['alg2n_qubit2identify_num'].items():
            for n_qubit, identify_num in n_qubit2identify_num.items():
                # alg2n_qubit2bug_num[alg_name][n_qubit] += bug_num
                alg2n_qubit2identify_num[alg_name][findRange(n_qubit,bug_num_ranges)] += identify_num  
            
# alg_names = list(alg_names)
# qubit_nums = list(qubit_nums)
# alg_names.sort()
# qubit_nums.sort()
# alg_names, qubit_nums

# %%
def combine_error(dict1, dict2, default_value = 1):
    all_values = []
    new_dict = defaultdict(lambda: defaultdict(lambda: default_value))
    for k1, v1 in dict1.items():
        for k2, v2 in v1.items():
            new_dict[k1][k2] = v2 / (dict2[k1][k2] + v2)
            all_values.append(v2 / (dict2[k1][k2] + v2))
    
    return new_dict, np.array(all_values)

# %%
alg2n_qubit2error_rate, all_values = combine(alg2n_qubit2error_num, alg2n_qubit2identify_num, 0)
alg2n_qubit2error_rate, np.mean(all_values)
# Out:
# (defaultdict(<function __main__.combine.<locals>.<lambda>()>,
#              {'hamiltonian_simulation': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.013836477987421384,
#                            (30, 35): 0.012962962962962963,
#                            None: 0.008138020833333334,
#                            (45, 50): 0.003763440860215054,
#                            (40, 45): 0.004819277108433735,
#                            (20, 25): 0.008914728682170543,
#                            (10, 15): 0.005376344086021506,
#                            (15, 20): 0.012121212121212121,
#                            (35, 40): 0.0073059360730593605}),
#               'qknn': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.024509803921568627,
#                            None: 0.04924242424242424,
#                            (45, 50): 0.028954802259887006,
#                            (10, 15): 0.054878048780487805,
#                            (20, 25): 0.015060240963855422,
#                            (40, 45): 0.023734177215189875,
#                            (15, 20): 0.040697674418604654,
#                            (30, 35): 0.02074688796680498,
#                            (35, 40): 0.025089605734767026}),
#               'qsvm': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.0035984848484848487,
#                            None: 0.003532182103610675,
#                            (45, 50): 0.003771551724137931,
#                            (40, 45): 0.0036231884057971015,
#                            (20, 25): 0.0025700934579439253,
#                            (15, 20): 0.001524390243902439,
#                            (10, 15): 0.001953125,
#                            (35, 40): 0.003983516483516483,
#                            (30, 35): 0.0025477707006369425}),
#               'vqc': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.003246013667425968,
#                            (30, 35): 0.003623490212411495,
#                            None: 0.028340918494000826,
#                            (45, 50): 0.025111426256077797,
#                            (10, 15): 0.0021645021645021645,
#                            (40, 45): 0.015735404660486094,
#                            (20, 25): 0.0027250206440957887,
#                            (15, 20): 0.0019582245430809398,
#                            (35, 40): 0.008630006357279084}),
#               'ising': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.017697594501718213,
#                            (30, 35): 0.013583815028901734,
#                            None: 0.008718861209964414,
#                            (45, 50): 0.005968688845401174,
#                            (10, 15): 0.013545347467608953,
#                            (40, 45): 0.00581140350877193,
#                            (20, 25): 0.020127118644067795,
#                            (15, 20): 0.021270718232044197,
#                            (35, 40): 0.009476309226932668}),
#               'ghz': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.011111111111111112,
#                            None: 0.0057692307692307696,
#                            (10, 15): 0.040123456790123455,
#                            (40, 45): 0.004761904761904762,
#                            (15, 20): 0.014705882352941176,
#                            (35, 40): 0.005405405405405406,
#                            (45, 50): 0.0031914893617021275,
#                            (30, 35): 0.0046875}),
#               'qft_inverse': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.0012303149606299212,
#                            None: 0.0003495892326516343,
#                            (45, 50): 0.0008928951060844423,
#                            (10, 15): 0.00629458665547629,
#                            (40, 45): 0.000581426079602516,
#                            (15, 20): 0.0020431990659661413,
#                            (20, 25): 0.0018165304268846503,
#                            (35, 40): 0.0009455626097528029,
#                            (30, 35): 0.0007126948775055679}),
#               'qnn': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.009414225941422594,
#                            None: 0.006048387096774193,
#                            (10, 15): 0.014534883720930232,
#                            (45, 50): 0.013092269326683292,
#                            (20, 25): 0.012162162162162163,
#                            (40, 45): 0.016853932584269662,
#                            (35, 40): 0.025,
#                            (15, 20): 0.011450381679389313,
#                            (30, 35): 0.028169014084507043}),
#               'deutsch_jozsa': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.017241379310344827,
#                            (30, 35): 0.010262725779967159,
#                            None: 0.01160541586073501,
#                            (45, 50): 0.01686946902654867,
#                            (10, 15): 0.018333333333333333,
#                            (40, 45): 0.013011152416356878,
#                            (20, 25): 0.011876484560570071,
#                            (15, 20): 0.016719745222929936,
#                            (35, 40): 0.018059490084985835}),
#               'bernstein_vazirani': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.01893939393939394,
#                            None: 0.01025236593059937,
#                            (45, 50): 0.014705882352941176,
#                            (40, 45): 0.012845849802371542,
#                            (20, 25): 0.012357414448669201,
#                            (10, 15): 0.026381909547738693,
#                            (15, 20): 0.015776699029126214,
#                            (35, 40): 0.011538461538461539,
#                            (30, 35): 0.0133248730964467}),
#               'qec_5_x': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(30, 35): 0.03571428571428571,
#                            (10, 15): 0.0625,
#                            (45, 50): 0.09523809523809523,
#                            (40, 45): 0.06696428571428571,
#                            None: 0.025,
#                            (20, 25): 0.05357142857142857,
#                            (15, 20): 0.08333333333333333,
#                            (35, 40): 0.061224489795918366,
#                            (25, 30): 0.12857142857142856}),
#               'swap': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {None: 0.05397727272727273,
#                            (45, 50): 0.01618705035971223,
#                            (20, 25): 0.033582089552238806,
#                            (10, 15): 0.07352941176470588,
#                            (35, 40): 0.020089285714285716,
#                            (30, 35): 0.035,
#                            (15, 20): 0.02040816326530612,
#                            (25, 30): 0.026470588235294117,
#                            (40, 45): 0.008064516129032258}),
#               'simon': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {None: 0.022727272727272728,
#                            (40, 45): 0.01,
#                            (20, 25): 0.015486725663716814,
#                            (10, 15): 0.015432098765432098,
#                            (30, 35): 0.010736196319018405,
#                            (15, 20): 0.00847457627118644,
#                            (25, 30): 0.016483516483516484,
#                            (45, 50): 0.009259259259259259,
#                            (35, 40): 0.003875968992248062}),
#               'grover': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {None: 0.058734939759036146,
#                            (10, 15): 0.03983833718244804,
#                            (15, 20): 0.026404494382022473,
#                            (20, 25): 0.021634615384615384}),
#               'qugan': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {None: 0.013020833333333334,
#                            (10, 15): 0.022727272727272728,
#                            (40, 45): 0.016304347826086956,
#                            (25, 30): 0.008108108108108109,
#                            (45, 50): 0.01045016077170418,
#                            (35, 40): 0.009072580645161291,
#                            (15, 20): 0.019801980198019802,
#                            (30, 35): 0.00909090909090909,
#                            (20, 25): 0.0017482517482517483}),
#               'multiplier': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {None: 0.0008771929824561404,
#                            (10, 15): 0.017857142857142856,
#                            (20, 25): 0.001968503937007874,
#                            (45, 50): 0.000362844702467344,
#                            (35, 40): 0.0012224938875305623,
#                            (15, 20): 0.003676470588235294,
#                            (30, 35): 0.0008417508417508417,
#                            (25, 30): 0.0012315270935960591}),
#               'qft': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.00012748597654258032,
#                            (45, 50): 0.00013018573164381183,
#                            (40, 45): 0.00010813148788927336})}),
#  0.01716916581933827)

# %%
alg2n_qubit2error_rate, all_values = combine_error(alg2n_qubit2error_num, alg2n_qubit2success_num, 0)
alg2n_qubit2error_rate, np.mean(all_values)
# Out:
# (defaultdict(<function __main__.combine_error.<locals>.<lambda>()>,
#              {'hamiltonian_simulation': defaultdict(<function __main__.combine_error.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.8301886792452831,
#                            (30, 35): 0.8166666666666667,
#                            None: 0.6756756756756757,
#                            (45, 50): 0.6774193548387096,
#                            (40, 45): 0.8275862068965517,
#                            (20, 25): 0.6764705882352942,
#                            (10, 15): 0.3448275862068966,
#                            (15, 20): 0.6666666666666666,
#                            (35, 40): 0.7804878048780488}),
#               'qknn': defaultdict(<function __main__.combine_error.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.5555555555555556,
#                            None: 0.6724137931034483,
#                            (45, 50): 0.7454545454545455,
#                            (10, 15): 0.54,
#                            (20, 25): 0.4166666666666667,
#                            (40, 45): 0.75,
#                            (15, 20): 0.5675675675675675,
#                            (30, 35): 0.5882352941176471,
#                            (35, 40): 0.717948717948718}),
#               'qsvm': defaultdict(<function __main__.combine_error.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.6333333333333333,
#                            None: 0.5625,
#                            (45, 50): 0.7777777777777778,
#                            (40, 45): 0.7692307692307693,
#                            (20, 25): 0.55,
#                            (15, 20): 0.38461538461538464,
#                            (10, 15): 0.23076923076923078,
#                            (35, 40): 0.8055555555555556,
#                            (30, 35): 0.5714285714285714}),
#               'vqc': defaultdict(<function __main__.combine_error.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.8636363636363636,
#                            (30, 35): 0.9157894736842105,
#                            None: 0.986321094312455,
#                            (45, 50): 0.9935871743486974,
#                            (10, 15): 0.5333333333333333,
#                            (40, 45): 0.9874213836477987,
#                            (20, 25): 0.825,
#                            (15, 20): 0.6666666666666666,
#                            (35, 40): 0.9679144385026738}),
#               'ising': defaultdict(<function __main__.combine_error.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.8442622950819673,
#                            (30, 35): 0.831858407079646,
#                            None: 0.6901408450704225,
#                            (45, 50): 0.7530864197530864,
#                            (10, 15): 0.647887323943662,
#                            (40, 45): 0.726027397260274,
#                            (20, 25): 0.8482142857142857,
#                            (15, 20): 0.8105263157894737,
#                            (35, 40): 0.7916666666666666}),
#               'ghz': defaultdict(<function __main__.combine_error.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.23076923076923078,
#                            None: 0.12,
#                            (10, 15): 0.3333333333333333,
#                            (40, 45): 0.16666666666666666,
#                            (15, 20): 0.20833333333333334,
#                            (35, 40): 0.16666666666666666,
#                            (45, 50): 0.14285714285714285,
#                            (30, 35): 0.13636363636363635}),
#               'qft_inverse': defaultdict(<function __main__.combine_error.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.4,
#                            None: 0.17391304347826086,
#                            (45, 50): 0.6,
#                            (10, 15): 0.375,
#                            (40, 45): 0.4583333333333333,
#                            (15, 20): 0.3333333333333333,
#                            (20, 25): 0.43478260869565216,
#                            (35, 40): 0.5384615384615384,
#                            (30, 35): 0.3333333333333333}),
#               'qnn': defaultdict(<function __main__.combine_error.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.5625,
#                            None: 0.46153846153846156,
#                            (10, 15): 0.38461538461538464,
#                            (45, 50): 0.7777777777777778,
#                            (20, 25): 0.5625,
#                            (40, 45): 0.75,
#                            (35, 40): 0.8648648648648649,
#                            (15, 20): 0.5,
#                            (30, 35): 0.8}),
#               'deutsch_jozsa': defaultdict(<function __main__.combine_error.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.7058823529411765,
#                            (30, 35): 0.625,
#                            None: 0.5106382978723404,
#                            (45, 50): 0.7625,
#                            (10, 15): 0.4782608695652174,
#                            (40, 45): 0.6885245901639344,
#                            (20, 25): 0.5263157894736842,
#                            (15, 20): 0.5384615384615384,
#                            (35, 40): 0.75}),
#               'bernstein_vazirani': defaultdict(<function __main__.combine_error.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.7575757575757576,
#                            None: 0.38235294117647056,
#                            (45, 50): 0.7727272727272727,
#                            (40, 45): 0.7428571428571429,
#                            (20, 25): 0.5909090909090909,
#                            (10, 15): 0.525,
#                            (15, 20): 0.5416666666666666,
#                            (35, 40): 0.7241379310344828,
#                            (30, 35): 0.7241379310344828}),
#               'qec_5_x': defaultdict(<function __main__.combine_error.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(30, 35): 0.6,
#                            (10, 15): 0.5384615384615384,
#                            (45, 50): 0.8571428571428571,
#                            (40, 45): 0.8333333333333334,
#                            None: 0.7777777777777778,
#                            (20, 25): 0.6666666666666666,
#                            (15, 20): 0.6363636363636364,
#                            (35, 40): 0.9230769230769231,
#                            (25, 30): 0.9}),
#               'swap': defaultdict(<function __main__.combine_error.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {None: 0.7307692307692307,
#                            (45, 50): 0.6428571428571429,
#                            (20, 25): 0.6,
#                            (10, 15): 0.5555555555555556,
#                            (35, 40): 0.6923076923076923,
#                            (30, 35): 0.7,
#                            (15, 20): 0.3333333333333333,
#                            (25, 30): 0.6428571428571429,
#                            (40, 45): 0.3333333333333333}),
#               'simon': defaultdict(<function __main__.combine_error.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {None: 0.5555555555555556,
#                            (40, 45): 0.6,
#                            (20, 25): 0.4666666666666667,
#                            (10, 15): 0.3333333333333333,
#                            (30, 35): 0.5833333333333334,
#                            (15, 20): 0.25,
#                            (25, 30): 0.6,
#                            (45, 50): 0.6666666666666666,
#                            (35, 40): 0.3333333333333333}),
#               'grover': defaultdict(<function __main__.combine_error.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {None: 0.7090909090909091,
#                            (10, 15): 0.7340425531914894,
#                            (15, 20): 0.7121212121212122,
#                            (20, 25): 0.8181818181818182}),
#               'qugan': defaultdict(<function __main__.combine_error.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {None: 0.5882352941176471,
#                            (10, 15): 0.46153846153846156,
#                            (40, 45): 0.8181818181818182,
#                            (25, 30): 0.5,
#                            (45, 50): 0.6842105263157895,
#                            (35, 40): 0.6428571428571429,
#                            (15, 20): 0.5714285714285714,
#                            (30, 35): 0.6666666666666666,
#                            (20, 25): 0.16666666666666666}),
#               'multiplier': defaultdict(<function __main__.combine_error.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {None: 0.42857142857142855,
#                            (10, 15): 0.3333333333333333,
#                            (20, 25): 0.2,
#                            (45, 50): 0.3333333333333333,
#                            (35, 40): 0.3333333333333333,
#                            (15, 20): 0.2,
#                            (30, 35): 0.2,
#                            (25, 30): 0.2}),
#               'qft': defaultdict(<function __main__.combine_error.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {(25, 30): 0.14285714285714285,
#                            (45, 50): 0.2,
#                            (40, 45): 0.14285714285714285})}),
#  0.5794393296155459)

# %%
alg2n_qubit2error_num,alg2n_qubit2success_num
# Out:
# (defaultdict(<function __main__.<lambda>()>,
#              {'hamiltonian_simulation': defaultdict(int,
#                           {(25, 30): 44,
#                            (30, 35): 49,
#                            None: 25,
#                            (45, 50): 21,
#                            (40, 45): 24,
#                            (20, 25): 23,
#                            (10, 15): 10,
#                            (15, 20): 24,
#                            (35, 40): 32}),
#               'qknn': defaultdict(int,
#                           {(25, 30): 20,
#                            None: 39,
#                            (45, 50): 41,
#                            (10, 15): 27,
#                            (20, 25): 10,
#                            (40, 45): 30,
#                            (15, 20): 21,
#                            (30, 35): 20,
#                            (35, 40): 28}),
#               'qsvm': defaultdict(int,
#                           {(25, 30): 19,
#                            None: 18,
#                            (45, 50): 35,
#                            (40, 45): 30,
#                            (20, 25): 11,
#                            (15, 20): 5,
#                            (10, 15): 6,
#                            (35, 40): 29,
#                            (30, 35): 16}),
#               'vqc': defaultdict(int,
#                           {(25, 30): 114,
#                            (30, 35): 174,
#                            None: 1370,
#                            (45, 50): 2479,
#                            (10, 15): 24,
#                            (40, 45): 1256,
#                            (20, 25): 66,
#                            (15, 20): 30,
#                            (35, 40): 543}),
#               'ising': defaultdict(int,
#                           {(25, 30): 103,
#                            (30, 35): 94,
#                            None: 49,
#                            (45, 50): 61,
#                            (10, 15): 46,
#                            (40, 45): 53,
#                            (20, 25): 95,
#                            (15, 20): 77,
#                            (35, 40): 76}),
#               'ghz': defaultdict(int,
#                           {(25, 30): 6,
#                            None: 3,
#                            (10, 15): 13,
#                            (40, 45): 4,
#                            (15, 20): 5,
#                            (35, 40): 4,
#                            (45, 50): 3,
#                            (30, 35): 3}),
#               'qft_inverse': defaultdict(int,
#                           {(25, 30): 10,
#                            None: 4,
#                            (45, 50): 21,
#                            (10, 15): 15,
#                            (40, 45): 11,
#                            (15, 20): 7,
#                            (20, 25): 10,
#                            (35, 40): 14,
#                            (30, 35): 8}),
#               'qnn': defaultdict(int,
#                           {(25, 30): 9,
#                            None: 6,
#                            (10, 15): 5,
#                            (45, 50): 21,
#                            (20, 25): 9,
#                            (40, 45): 12,
#                            (35, 40): 32,
#                            (15, 20): 6,
#                            (30, 35): 16}),
#               'deutsch_jozsa': defaultdict(int,
#                           {(25, 30): 36,
#                            (30, 35): 25,
#                            None: 24,
#                            (45, 50): 61,
#                            (10, 15): 22,
#                            (40, 45): 42,
#                            (20, 25): 20,
#                            (15, 20): 21,
#                            (35, 40): 51}),
#               'bernstein_vazirani': defaultdict(int,
#                           {(25, 30): 25,
#                            None: 13,
#                            (45, 50): 34,
#                            (40, 45): 26,
#                            (20, 25): 13,
#                            (10, 15): 21,
#                            (15, 20): 13,
#                            (35, 40): 21,
#                            (30, 35): 21}),
#               'qec_5_x': defaultdict(int,
#                           {(30, 35): 6,
#                            (10, 15): 7,
#                            (45, 50): 24,
#                            (40, 45): 15,
#                            None: 7,
#                            (20, 25): 6,
#                            (15, 20): 7,
#                            (35, 40): 12,
#                            (25, 30): 18}),
#               'swap': defaultdict(int,
#                           {None: 19,
#                            (45, 50): 9,
#                            (20, 25): 9,
#                            (10, 15): 10,
#                            (35, 40): 9,
#                            (30, 35): 7,
#                            (15, 20): 4,
#                            (25, 30): 9,
#                            (40, 45): 2}),
#               'simon': defaultdict(int,
#                           {None: 10,
#                            (40, 45): 9,
#                            (20, 25): 7,
#                            (10, 15): 5,
#                            (30, 35): 7,
#                            (15, 20): 2,
#                            (25, 30): 6,
#                            (45, 50): 6,
#                            (35, 40): 2}),
#               'grover': defaultdict(int,
#                           {None: 39, (10, 15): 69, (15, 20): 47, (20, 25): 9}),
#               'qugan': defaultdict(int,
#                           {None: 10,
#                            (10, 15): 6,
#                            (40, 45): 9,
#                            (25, 30): 6,
#                            (45, 50): 13,
#                            (35, 40): 9,
#                            (15, 20): 8,
#                            (30, 35): 4,
#                            (20, 25): 1}),
#               'multiplier': defaultdict(int,
#                           {None: 3,
#                            (10, 15): 4,
#                            (20, 25): 1,
#                            (45, 50): 1,
#                            (35, 40): 2,
#                            (15, 20): 1,
#                            (30, 35): 1,
#                            (25, 30): 1}),
#               'qft': defaultdict(int,
#                           {(25, 30): 1, (45, 50): 3, (40, 45): 2})}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'hamiltonian_simulation': defaultdict(int,
#                           {(25, 30): 9,
#                            (30, 35): 11,
#                            None: 12,
#                            (45, 50): 10,
#                            (10, 15): 19,
#                            (20, 25): 11,
#                            (40, 45): 5,
#                            (15, 20): 12,
#                            (35, 40): 9}),
#               'qknn': defaultdict(int,
#                           {(25, 30): 16,
#                            None: 19,
#                            (45, 50): 14,
#                            (10, 15): 23,
#                            (40, 45): 10,
#                            (20, 25): 14,
#                            (15, 20): 16,
#                            (30, 35): 14,
#                            (35, 40): 11}),
#               'qsvm': defaultdict(int,
#                           {(30, 35): 12,
#                            None: 14,
#                            (10, 15): 20,
#                            (40, 45): 9,
#                            (20, 25): 9,
#                            (25, 30): 11,
#                            (45, 50): 10,
#                            (15, 20): 8,
#                            (35, 40): 7}),
#               'ising': defaultdict(int,
#                           {(25, 30): 19,
#                            (30, 35): 19,
#                            None: 22,
#                            (45, 50): 20,
#                            (10, 15): 25,
#                            (40, 45): 20,
#                            (20, 25): 17,
#                            (15, 20): 18,
#                            (35, 40): 20}),
#               'qft': defaultdict(int,
#                           {(30, 35): 17,
#                            None: 11,
#                            (45, 50): 12,
#                            (10, 15): 16,
#                            (20, 25): 11,
#                            (40, 45): 12,
#                            (15, 20): 12,
#                            (25, 30): 6,
#                            (35, 40): 13}),
#               'ghz': defaultdict(int,
#                           {(25, 30): 20,
#                            (30, 35): 19,
#                            None: 22,
#                            (45, 50): 18,
#                            (10, 15): 26,
#                            (40, 45): 20,
#                            (20, 25): 18,
#                            (15, 20): 19,
#                            (35, 40): 20}),
#               'qft_inverse': defaultdict(int,
#                           {(25, 30): 15,
#                            None: 19,
#                            (45, 50): 14,
#                            (10, 15): 25,
#                            (40, 45): 13,
#                            (20, 25): 13,
#                            (30, 35): 16,
#                            (15, 20): 14,
#                            (35, 40): 12}),
#               'qnn': defaultdict(int,
#                           {(25, 30): 7,
#                            None: 7,
#                            (10, 15): 8,
#                            (45, 50): 6,
#                            (20, 25): 7,
#                            (40, 45): 4,
#                            (15, 20): 6,
#                            (35, 40): 5,
#                            (30, 35): 4}),
#               'qugan': defaultdict(int,
#                           {(25, 30): 6,
#                            None: 7,
#                            (10, 15): 7,
#                            (45, 50): 6,
#                            (20, 25): 5,
#                            (15, 20): 6,
#                            (35, 40): 5,
#                            (30, 35): 2,
#                            (40, 45): 2}),
#               'deutsch_jozsa': defaultdict(int,
#                           {(25, 30): 15,
#                            None: 23,
#                            (45, 50): 19,
#                            (10, 15): 24,
#                            (40, 45): 19,
#                            (20, 25): 18,
#                            (15, 20): 18,
#                            (35, 40): 17,
#                            (30, 35): 15}),
#               'bernstein_vazirani': defaultdict(int,
#                           {(25, 30): 8,
#                            None: 21,
#                            (45, 50): 10,
#                            (10, 15): 19,
#                            (40, 45): 9,
#                            (20, 25): 9,
#                            (30, 35): 8,
#                            (35, 40): 8,
#                            (15, 20): 11}),
#               'multiplier': defaultdict(int,
#                           {(30, 35): 4,
#                            None: 4,
#                            (10, 15): 8,
#                            (45, 50): 2,
#                            (40, 45): 2,
#                            (20, 25): 4,
#                            (15, 20): 4,
#                            (35, 40): 4,
#                            (25, 30): 4}),
#               'qec_5_x': defaultdict(int,
#                           {(30, 35): 4,
#                            None: 2,
#                            (10, 15): 6,
#                            (45, 50): 4,
#                            (40, 45): 3,
#                            (20, 25): 3,
#                            (15, 20): 4,
#                            (35, 40): 1,
#                            (25, 30): 2}),
#               'vqc': defaultdict(int,
#                           {None: 19,
#                            (45, 50): 16,
#                            (10, 15): 21,
#                            (40, 45): 16,
#                            (20, 25): 14,
#                            (15, 20): 15,
#                            (25, 30): 18,
#                            (30, 35): 16,
#                            (35, 40): 18}),
#               'swap': defaultdict(int,
#                           {None: 7,
#                            (10, 15): 8,
#                            (45, 50): 5,
#                            (20, 25): 6,
#                            (40, 45): 4,
#                            (15, 20): 8,
#                            (25, 30): 5,
#                            (30, 35): 3,
#                            (35, 40): 4}),
#               'simon': defaultdict(int,
#                           {None: 8,
#                            (10, 15): 10,
#                            (40, 45): 6,
#                            (20, 25): 8,
#                            (25, 30): 4,
#                            (15, 20): 6,
#                            (30, 35): 5,
#                            (35, 40): 4,
#                            (45, 50): 3}),
#               'grover': defaultdict(int,
#                           {None: 16,
#                            (10, 15): 25,
#                            (15, 20): 19,
#                            (20, 25): 2})}))

# %%
# index: qubit_nums:
# cols: alg_names

alg_names = list(alg2n_qubit2error_rate.keys())
# qubit_nums = list(range(10, 30))
# qubit_nums.sort()
alg_names.sort()

# alg_names, qubit_nums

data = np.zeros((len(bug_num_ranges) , len(alg_names))) # 先index, 后column 

for r_i, qubit_num in enumerate(bug_num_ranges):
    for c_i, alg_name in enumerate(alg_names):
        data[r_i][c_i] = alg2n_qubit2error_rate[alg_name][qubit_num]

# cbar
df = pd.DataFrame(data, index=bug_num_ranges, columns=alg_names)
fig = sns.heatmap(data=df,cmap='OrRd')
fig.get_figure().savefig('error_rate.svg')
data
# Out:
# array([[0.525     , 0.47826087, 0.33333333, 0.73404255, 0.34482759,
#         0.64788732, 0.33333333, 0.53846154, 0.        , 0.375     ,
#         0.54      , 0.38461538, 0.23076923, 0.46153846, 0.33333333,
#         0.55555556, 0.53333333],
#        [0.54166667, 0.53846154, 0.20833333, 0.71212121, 0.66666667,
#         0.81052632, 0.2       , 0.63636364, 0.        , 0.33333333,
#         0.56756757, 0.5       , 0.38461538, 0.57142857, 0.25      ,
#         0.33333333, 0.66666667],
#        [0.59090909, 0.52631579, 0.        , 0.81818182, 0.67647059,
#         0.84821429, 0.2       , 0.66666667, 0.        , 0.43478261,
#         0.41666667, 0.5625    , 0.55      , 0.16666667, 0.46666667,
#         0.6       , 0.825     ],
#        [0.75757576, 0.70588235, 0.23076923, 0.        , 0.83018868,
#         0.8442623 , 0.2       , 0.9       , 0.14285714, 0.4       ,
#         0.55555556, 0.5625    , 0.63333333, 0.5       , 0.6       ,
#         0.64285714, 0.86363636],
#        [0.72413793, 0.625     , 0.13636364, 0.        , 0.81666667,
#         0.83185841, 0.2       , 0.6       , 0.        , 0.33333333,
#         0.58823529, 0.8       , 0.57142857, 0.66666667, 0.58333333,
#         0.7       , 0.91578947],
#        [0.72413793, 0.75      , 0.16666667, 0.        , 0.7804878 ,
#         0.79166667, 0.33333333, 0.92307692, 0.        , 0.53846154,
#         0.71794872, 0.86486486, 0.80555556, 0.64285714, 0.33333333,
#         0.69230769, 0.96791444],
#        [0.74285714, 0.68852459, 0.16666667, 0.        , 0.82758621,
#         0.7260274 , 0.        , 0.83333333, 0.14285714, 0.45833333,
#         0.75      , 0.75      , 0.76923077, 0.81818182, 0.6       ,
#         0.33333333, 0.98742138],
#        [0.77272727, 0.7625    , 0.14285714, 0.        , 0.67741935,
#         0.75308642, 0.33333333, 0.85714286, 0.2       , 0.6       ,
#         0.74545455, 0.77777778, 0.77777778, 0.68421053, 0.66666667,
#         0.64285714, 0.99358717]])

# %%
alg2n_qubit2success_num = defaultdict(lambda: defaultdict(int))
alg2n_qubit2bug_num = defaultdict(lambda: defaultdict(int))

for result in all_results:
    min_qubit_num, max_qubit_num, bug_num_index, max_step = result['key']
    if max_step == 4:
    
        for alg_name, n_qubit2success_num in result['alg2n_qubit2success_num'].items():
            for n_qubit, success_num in n_qubit2success_num.items():
                # alg2n_qubit2success_num[alg_name][n_qubit] += success_num 
                alg2n_qubit2success_num[alg_name][bug_num_index] += success_num 
                
    
        for alg_name, n_qubit2bug_num in result['alg2n_qubit2bug_num'].items():
            for n_qubit, bug_num in n_qubit2bug_num.items():
                # alg2n_qubit2bug_num[alg_name][n_qubit] += bug_num
                alg2n_qubit2bug_num[alg_name][bug_num_index] += bug_num  
            
alg2n_qubit2success_rate, all_values = combine(alg2n_qubit2success_num, alg2n_qubit2bug_num)
alg2n_qubit2success_rate, np.mean(all_values)
# Out:
# (defaultdict(<function __main__.combine.<locals>.<lambda>()>,
#              {'hamiltonian_simulation': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {1: 0.4166666666666667,
#                            3: 0.5208333333333334,
#                            4: 0.6458333333333334,
#                            2: 0.4583333333333333}),
#               'qknn': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {1: 0.4791666666666667,
#                            3: 0.8333333333333334,
#                            4: 0.8958333333333334,
#                            2: 0.6458333333333334}),
#               'qsvm': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {1: 0.14583333333333334,
#                            3: 0.625,
#                            4: 0.7291666666666666,
#                            2: 0.5833333333333334}),
#               'ising': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {1: 0.7916666666666666,
#                            3: 1.0,
#                            4: 1.0,
#                            2: 0.9583333333333334}),
#               'qft': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {1: 0.3541666666666667,
#                            3: 0.6666666666666666,
#                            4: 0.75,
#                            2: 0.5208333333333334}),
#               'ghz': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {1: 0.8958333333333334,
#                            3: 0.9791666666666666,
#                            4: 1.0,
#                            2: 0.9166666666666666}),
#               'qft_inverse': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {1: 0.3958333333333333,
#                            3: 0.9375,
#                            4: 0.9791666666666666,
#                            2: 0.625}),
#               'qnn': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {1: 0.625, 3: 0.9375, 4: 1.0, 2: 0.8125}),
#               'qugan': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {1: 0.25, 3: 0.9375, 4: 1.0, 2: 0.6875}),
#               'deutsch_jozsa': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {1: 0.7083333333333334,
#                            3: 0.9375,
#                            4: 0.9583333333333334,
#                            2: 0.8958333333333334}),
#               'bernstein_vazirani': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {1: 0.2708333333333333,
#                            3: 0.6875,
#                            4: 0.8125,
#                            2: 0.375}),
#               'multiplier': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {1: 0.8, 4: 1.0, 3: 0.9, 2: 0.9}),
#               'qec_5_x': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {1: 0.4, 4: 0.9, 3: 0.9, 2: 0.7}),
#               'vqc': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {3: 0.9583333333333334,
#                            4: 0.9791666666666666,
#                            1: 0.3958333333333333,
#                            2: 0.8541666666666666}),
#               'swap': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {3: 0.875, 4: 1.0, 2: 0.75, 1: 0.5}),
#               'simon': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {3: 0.875,
#                            4: 0.7916666666666666,
#                            2: 0.4583333333333333,
#                            1: 0.125}),
#               'grover': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                           {3: 0.9411764705882353,
#                            1: 0.8235294117647058,
#                            4: 1.0,
#                            2: 0.8823529411764706})}),
#  0.7405204728950403)

# %%
0.6664332399626516,0.7165188869665513,0.7405204728950403
# Out:
# (0.6664332399626516, 0.7165188869665513, 0.7405204728950403)

# %%
# index: qubit_nums:
# cols: alg_names

alg_names = list(alg2n_qubit2success_rate.keys())
# qubit_nums = list(range(10, 30))
# qubit_nums.sort()
alg_names.sort()

# alg_names, qubit_nums
bug_num_ranges = [1,2,3,4]
data = np.zeros((len(bug_num_ranges) , len(alg_names))) # 先index, 后column

for r_i, qubit_num in enumerate(bug_num_ranges):
    for c_i, alg_name in enumerate(alg_names):
        data[r_i][c_i] = alg2n_qubit2success_rate[alg_name][qubit_num]

df = pd.DataFrame(data, index=bug_num_ranges, columns=alg_names)
fig = sns.heatmap(data=df,cmap='OrRd')
fig.get_figure().savefig('success_rate_bug_num.svg')
print(data.T)
data.mean(axis =1)
# Out:
# [[0.27083333 0.375      0.6875     0.8125    ]
#  [0.70833333 0.89583333 0.9375     0.95833333]
#  [0.89583333 0.91666667 0.97916667 1.        ]
#  [0.82352941 0.88235294 0.94117647 1.        ]
#  [0.41666667 0.45833333 0.52083333 0.64583333]
#  [0.79166667 0.95833333 1.         1.        ]
#  [0.8        0.9        0.9        1.        ]
#  [0.4        0.7        0.9        0.9       ]
#  [0.35416667 0.52083333 0.66666667 0.75      ]
#  [0.39583333 0.625      0.9375     0.97916667]
#  [0.47916667 0.64583333 0.83333333 0.89583333]
#  [0.625      0.8125     0.9375     1.        ]
#  [0.14583333 0.58333333 0.625      0.72916667]
#  [0.25       0.6875     0.9375     1.        ]
#  [0.125      0.45833333 0.875      0.79166667]
#  [0.5        0.75       0.875      1.        ]
#  [0.39583333 0.85416667 0.95833333 0.97916667]]
# array([0.49280565, 0.70729527, 0.85364764, 0.90833333])
