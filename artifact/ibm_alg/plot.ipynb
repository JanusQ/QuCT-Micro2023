# %%
import pickle
steps = pickle.load(open('steps.pkl','rb'))

# %%
step0, step1, step2,step3 = steps

# %%
quest = pickle.load(open('quest.pkl','rb'))
rb = pickle.load(open('rb.pkl','rb'))

# %%
import seaborn as sns 
ax = sns.boxplot([rb, step0, step1, quest, step2, step3])
fig = ax.get_figure()
fig.savefig('boxplot.svg')
