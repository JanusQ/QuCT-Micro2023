# %%
from synthesis_baseline.qsd_csd.unitary import unitary as decompose_unitary
from qiskit import QuantumCircuit, transpile
from scipy.stats import unitary_group
from utils.backend import gen_grid_topology, get_grid_neighbor_info, Backend, gen_linear_topology, get_linear_neighbor_info
from qiskit.quantum_info import Operator

# %%
n_qubits = 7
topology = gen_linear_topology(n_qubits)
neigh_info = get_linear_neighbor_info(n_qubits, 1)

backend = Backend(n_qubits=n_qubits, topology=topology, neighbor_info=neigh_info, basis_single_gates=['u'],
                  basis_two_gates=['cz'], divide=False, decoupling=False)

# %%
def cnot_count(qc: QuantumCircuit):
    count_ops = qc.count_ops()
    if 'cx' in count_ops:
        return count_ops['cx']
    return 0


def cz_count(qc: QuantumCircuit):
    count_ops = qc.count_ops()
    if 'cz' in count_ops:
        return count_ops['cz']
    return 0

# %%
def my_transpile(circuit):
    return transpile(circuit, coupling_map=backend.coupling_map, basis_gates= ['u', 'cz'],initial_layout=list(range(n_qubits)), optimization_level=3)

# %%
for i in range(10):
    init_unitary_mat = unitary_group.rvs(2**n_qubits)
    csd = decompose_unitary(init_unitary_mat, decomposition='csd')
    csd = my_transpile(csd)

    qsd = decompose_unitary(init_unitary_mat, decomposition='qsd')
    qsd = my_transpile(qsd)

    qiskit_circuit = QuantumCircuit(n_qubits)
    qiskit_circuit.append(Operator(init_unitary_mat), list(range(n_qubits)))
    qiskit_circuit = my_transpile(qiskit_circuit)

    print('csd')
    print('gate = ', len(csd))
    print('#two-qubit gates = ', cnot_count(csd) + cz_count(csd))
    print('depth = ', csd.depth())
    print()


    print('qsd')
    print('gate = ', len(csd))
    print('#two-qubit gates = ', cnot_count(qsd) + cz_count(qsd))
    print('depth = ', qsd.depth())
    print()

    print('ccd')
    print('gate = ', len(qiskit_circuit))
    print('#two-qubit gates = ', cnot_count(qiskit_circuit) + cz_count(qiskit_circuit))
    print('depth = ', qiskit_circuit.depth())
    print('\n\n')
# Out:
# csd
# gate =  129490
# #two-qubit gates =  47081
# depth =  57733
#
# qsd
# gate =  129490
# #two-qubit gates =  20331
# depth =  36411
#
# ccd
# gate =  54571
# #two-qubit gates =  19261
# depth =  34293
#
#
#
# csd
# gate =  128487
# #two-qubit gates =  46661
# depth =  56996
#
# qsd
# gate =  128487
# #two-qubit gates =  20331
# depth =  36411
#
# ccd
# gate =  54584
# #two-qubit gates =  19267
# depth =  34305
#
#
#
# csd
# gate =  129643
# #two-qubit gates =  47137
# depth =  57981
#
# qsd
# gate =  129643
# #two-qubit gates =  20331
# depth =  36411
#
# ccd
# gate =  54584
# #two-qubit gates =  19267
# depth =  34305
#
#
#
# csd
# gate =  128835
# #two-qubit gates =  46803
# depth =  57387
#
# qsd
# gate =  128835
# #two-qubit gates =  20333
# depth =  36415
#
# ccd
# gate =  54581
# #two-qubit gates =  19265
# depth =  34301
#
#
#
# csd
# gate =  129487
# #two-qubit gates =  47079
# depth =  57717
#
# qsd
# gate =  129487
# #two-qubit gates =  20333
# depth =  36415
#
# ccd
# gate =  54571
# #two-qubit gates =  19261
# depth =  34293
#
#
#
# csd
# gate =  129190
# #two-qubit gates =  46961
# depth =  57402
#
# qsd
# gate =  129190
# #two-qubit gates =  20333
# depth =  36415
#
# ccd
# gate =  54574
# #two-qubit gates =  19263
# depth =  34297
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/luliqiang/QuCT-Micro2023/eval_qsd_csd_ccd.ipynb Cell 5 in 4
#       <a href='vscode-notebook-cell://ssh-remote%2B115.27.161.184/home/luliqiang/QuCT-Micro2023/eval_qsd_csd_ccd.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> init_unitary_mat = unitary_group.rvs(2**n_qubits)
#       <a href='vscode-notebook-cell://ssh-remote%2B115.27.161.184/home/luliqiang/QuCT-Micro2023/eval_qsd_csd_ccd.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> csd = decompose_unitary(init_unitary_mat, decomposition='csd')
# ----> <a href='vscode-notebook-cell://ssh-remote%2B115.27.161.184/home/luliqiang/QuCT-Micro2023/eval_qsd_csd_ccd.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> csd = my_transpile(csd)
#       <a href='vscode-notebook-cell://ssh-remote%2B115.27.161.184/home/luliqiang/QuCT-Micro2023/eval_qsd_csd_ccd.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> qsd = decompose_unitary(init_unitary_mat, decomposition='qsd')
#       <a href='vscode-notebook-cell://ssh-remote%2B115.27.161.184/home/luliqiang/QuCT-Micro2023/eval_qsd_csd_ccd.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> qsd = my_transpile(qsd)
#
# /home/luliqiang/QuCT-Micro2023/eval_qsd_csd_ccd.ipynb Cell 5 in 2
#       <a href='vscode-notebook-cell://ssh-remote%2B115.27.161.184/home/luliqiang/QuCT-Micro2023/eval_qsd_csd_ccd.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> def my_transpile(circuit):
# ----> <a href='vscode-notebook-cell://ssh-remote%2B115.27.161.184/home/luliqiang/QuCT-Micro2023/eval_qsd_csd_ccd.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     return transpile(circuit, coupling_map=backend.coupling_map, basis_gates= ['u', 'cz'],initial_layout=list(range(n_qubits)), optimization_level=3)
#
# File ~/miniconda3/envs/ISCA/lib/python3.9/site-packages/qiskit/compiler/transpiler.py:382, in transpile(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, callback, output_name, unitary_synthesis_method, unitary_synthesis_plugin_config, target, hls_config, init_method, optimization_method, ignore_backend_supplied_default_methods)
#     379     for circuit, unique_args in zip(circuits, unique_transpile_args):
#     380         transpile_config, pass_manager = _combine_args(shared_args, unique_args)
#     381         output_circuits.append(
# --> 382             _serial_transpile_circuit(
#     383                 circuit,
#     384                 pass_manager,
#     385                 transpile_config["callback"],
#     386                 transpile_config["output_name"],
#     387                 transpile_config["backend_num_qubits"],
#     388                 transpile_config["faulty_qubits_map"],
#     389                 transpile_config["pass_manager_config"].backend_properties,
#     390             )
#     391         )
#     392     circuits = output_circuits
#     393 end_time = time()
#
# File ~/miniconda3/envs/ISCA/lib/python3.9/site-packages/qiskit/compiler/transpiler.py:475, in _serial_transpile_circuit(circuit, pass_manager, callback, output_name, num_qubits, faulty_qubits_map, backend_prop)
#     466 def _serial_transpile_circuit(
#     467     circuit,
#     468     pass_manager,
#    (...)
#     473     backend_prop=None,
#     474 ):
# --> 475     result = pass_manager.run(circuit, callback=callback, output_name=output_name)
#     476     if faulty_qubits_map:
#     477         return _remap_circuit_faulty_backend(
#     478             result,
#     479             num_qubits,
#     480             backend_prop,
#     481             faulty_qubits_map,
#     482         )
#
# File ~/miniconda3/envs/ISCA/lib/python3.9/site-packages/qiskit/transpiler/passmanager.py:528, in StagedPassManager.run(self, circuits, output_name, callback)
#     521 def run(
#     522     self,
#     523     circuits: Union[QuantumCircuit, List[QuantumCircuit]],
#     524     output_name: str = None,
#     525     callback: Callable = None,
#     526 ) -> Union[QuantumCircuit, List[QuantumCircuit]]:
#     527     self._update_passmanager()
# --> 528     return super().run(circuits, output_name, callback)
#
# File ~/miniconda3/envs/ISCA/lib/python3.9/site-packages/qiskit/transpiler/passmanager.py:228, in PassManager.run(self, circuits, output_name, callback)
#     226     return circuits
#     227 if isinstance(circuits, QuantumCircuit):
# --> 228     return self._run_single_circuit(circuits, output_name, callback)
#     229 if len(circuits) == 1:
#     230     return self._run_single_circuit(circuits[0], output_name, callback)
#
# File ~/miniconda3/envs/ISCA/lib/python3.9/site-packages/qiskit/transpiler/passmanager.py:283, in PassManager._run_single_circuit(self, circuit, output_name, callback)
#     271 """Run all the passes on a ``circuit``.
#     272
#     273 Args:
#    (...)
#     280     The transformed circuit.
#     281 """
#     282 running_passmanager = self._create_running_passmanager()
# --> 283 result = running_passmanager.run(circuit, output_name=output_name, callback=callback)
#     284 self.property_set = running_passmanager.property_set
#     285 return result
#
# File ~/miniconda3/envs/ISCA/lib/python3.9/site-packages/qiskit/transpiler/runningpassmanager.py:125, in RunningPassManager.run(***failed resolving arguments***)
#     123 for passset in self.working_list:
#     124     for pass_ in passset:
# --> 125         dag = self._do_pass(pass_, dag, passset.options)
#     127 circuit = dag_to_circuit(dag)
#     128 if output_name:
#
# File ~/miniconda3/envs/ISCA/lib/python3.9/site-packages/qiskit/transpiler/runningpassmanager.py:172, in RunningPassManager._do_pass(self, pass_, dag, options)
#     170 # Run the pass itself, if not already run
#     171 if pass_ not in self.valid_passes:
# --> 172     dag = self._run_this_pass(pass_, dag)
#     174     # update the valid_passes property
#     175     self._update_valid_passes(pass_)
#
# File ~/miniconda3/envs/ISCA/lib/python3.9/site-packages/qiskit/transpiler/runningpassmanager.py:201, in RunningPassManager._run_this_pass(self, pass_, dag)
#     198 if pass_.is_transformation_pass:
#     199     # Measure time if we have a callback or logging set
#     200     start_time = time()
# --> 201     new_dag = pass_.run(dag)
#     202     end_time = time()
#     203     run_time = end_time - start_time
#
# File ~/miniconda3/envs/ISCA/lib/python3.9/site-packages/qiskit/transpiler/passes/synthesis/unitary_synthesis.py:308, in UnitarySynthesis.run(self, dag)
#     305 if self.method == "default":
#     306     # pylint: disable=attribute-defined-outside-init
#     307     plugin_method._approximation_degree = self._approximation_degree
# --> 308 return self._run_main_loop(
#     309     dag, plugin_method, plugin_kwargs, default_method, default_kwargs
#     310 )
#
# File ~/miniconda3/envs/ISCA/lib/python3.9/site-packages/qiskit/transpiler/passes/synthesis/unitary_synthesis.py:349, in UnitarySynthesis._run_main_loop(self, dag, plugin_method, plugin_kwargs, default_method, default_kwargs)
#     344 if method.supports_coupling_map:
#     345     kwargs["coupling_map"] = (
#     346         self._coupling_map,
#     347         [dag_bit_indices[x] for x in node.qargs],
#     348     )
# --> 349 synth_dag = method.run(unitary, **kwargs)
#     350 if synth_dag is not None:
#     351     if isinstance(synth_dag, tuple):
#
# File ~/miniconda3/envs/ISCA/lib/python3.9/site-packages/qiskit/transpiler/passes/synthesis/unitary_synthesis.py:558, in DefaultUnitarySynthesis.run(self, unitary, **options)
#     556     if not decomposer2q:
#     557         return None
# --> 558     synth_dag, wires = self._synth_natural_direction(
#     559         unitary,
#     560         coupling_map,
#     561         qubits,
#     562         decomposer2q,
#     563         gate_lengths,
#     564         gate_errors,
#     565         natural_direction,
#     566         approximation_degree,
#     567         pulse_optimize,
#     568         target,
#     569         preferred_direction,
#     570     )
#     571 else:
#     572     from qiskit.quantum_info.synthesis.qsd import (  # pylint: disable=cyclic-import
#     573         qs_decomposition,
#     574     )
#
# File ~/miniconda3/envs/ISCA/lib/python3.9/site-packages/qiskit/transpiler/passes/synthesis/unitary_synthesis.py:649, in DefaultUnitarySynthesis._synth_natural_direction(self, su4_mat, coupling_map, qubits, decomposer2q, gate_lengths, gate_errors, natural_direction, approximation_degree, pulse_optimize, target, preferred_direction)
#     647     basis_fidelity = physical_gate_fidelity
#     648 if not isinstance(decomposer2q, XXDecomposer):
# --> 649     synth_circ = decomposer2q(su4_mat, basis_fidelity=basis_fidelity)
#     650 else:
#     651     synth_circ = decomposer2q(su4_mat)
#
# File ~/miniconda3/envs/ISCA/lib/python3.9/site-packages/qiskit/quantum_info/synthesis/two_qubit_decompose.py:1120, in TwoQubitBasisDecomposer.__call__(self, target, basis_fidelity, _num_basis_uses)
#    1118     return_circuit.global_phase += np.pi
#    1119 for i in range(best_nbasis):
# -> 1120     return_circuit.compose(decomposition_euler[2 * i], [q[0]], inplace=True)
#    1121     return_circuit.compose(decomposition_euler[2 * i + 1], [q[1]], inplace=True)
#    1122     return_circuit.append(self.gate, [q[0], q[1]])
#
# File ~/miniconda3/envs/ISCA/lib/python3.9/site-packages/qiskit/circuit/quantumcircuit.py:936, in QuantumCircuit.compose(self, other, qubits, clbits, front, inplace, wrap)
#     931     raise CircuitError(
#     932         "Trying to compose with another QuantumCircuit which has more 'in' edges."
#     933     )
#     935 # number of qubits and clbits must match number in circuit or None
# --> 936 identity_qubit_map = dict(zip(other.qubits, dest.qubits))
#     937 identity_clbit_map = dict(zip(other.clbits, dest.clbits))
#     938 if qubits is None:
#
# KeyboardInterrupt:
